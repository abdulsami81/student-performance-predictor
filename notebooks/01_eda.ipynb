# %% [markdown]
#  Libraries Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


pd.set_option('display.max_columns', None)
sns.set_theme(style="whitegrid")

# %% [markdown]
# Data Load

# %%
df = pd.read_csv('E:\AI projects\student-performance-predictor\data\student-mat.csv', sep=';')

print("Shape:", df.shape)        
print("\nFirst 5 rows:")
df.head()
# Out:
# Shape: (395, 33)
#
# First 5 rows:
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\admin\AppData\Local\Temp\ipykernel_11256\1053675798.py:1: SyntaxWarning: invalid escape sequence '\A'
#   df = pd.read_csv('E:\AI projects\student-performance-predictor\data\student-mat.csv', sep=';')
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0  course   mother           2          2         0       yes     no   no
# ...

# %% [markdown]
# Basic Info

# %%
print("Column names:\n", df.columns.tolist())
print("\nData types:\n", df.dtypes)
print("\nMissing values:\n", df.isnull().sum())
print("\nBasic stats:")
df.describe()
# Out:
# Column names:
#  ['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2', 'G3']
#
# Data types:
#  school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# ...

# %% [markdown]
# Target Variable

# %%
plt.figure(figsize=(8, 4))
sns.histplot(df['G3'], bins=20, kde=True, color='steelblue')
plt.title('Distribution of Final Grades (G3)')
plt.xlabel('Final Grade')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

print("Average grade:", df['G3'].mean().round(2))
print("Std deviation:", df['G3'].std().round(2))
# Out:
# Average grade: 10.42
# Std deviation: 4.58

# %% [markdown]
# Correlation Heatmap

# %%
numeric_df = df.select_dtypes(include='number')

plt.figure(figsize=(12, 8))
sns.heatmap(numeric_df.corr(), annot=True, fmt='.2f',
            cmap='coolwarm', center=0)
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()

# %% [markdown]
#  Important Relationships

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# Study time vs Grade
sns.boxplot(x='studytime', y='G3', data=df, ax=axes[0])
axes[0].set_title('Study Time vs Final Grade')

# Absences vs Grade
sns.scatterplot(x='absences', y='G3', data=df, ax=axes[1], alpha=0.6)
axes[1].set_title('Absences vs Final Grade')

# G1, G2 vs G3
sns.scatterplot(x='G2', y='G3', data=df, ax=axes[2], alpha=0.6, color='green')
axes[2].set_title('Mid-term (G2) vs Final (G3)')

plt.tight_layout()
plt.show()
